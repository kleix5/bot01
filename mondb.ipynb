# %% [markdown]
# памятники - отдельные постройки, здания и сооружения с исторически сложившимися территориями (в том числе памятники религиозного назначения, относящиеся в соответствии с Федеральным законом от 30 ноября 2010 года N 327-ФЗ "О передаче религиозным организациям имущества религиозного назначения, находящегося в государственной или муниципальной собственности" к имуществу религиозного назначения); мемориальные квартиры; мавзолеи, отдельные захоронения; произведения монументального искусства; объекты науки и техники, включая военные; объекты археологического наследия;
#
# (в ред. Федеральных законов от 30.11.2010 N 328-ФЗ, от 23.07.2013 N 245-ФЗ, от 22.10.2014 N 315-ФЗ)

# %% [markdown]
# ансамбли - четко локализуемые на исторически сложившихся территориях группы изолированных или объединенных памятников, строений и сооружений фортификационного, дворцового, жилого, общественного, административного, торгового, производственного, научного, учебного назначения, а также памятников и сооружений религиозного назначения, в том числе фрагменты исторических планировок и застроек поселений, которые могут быть отнесены к градостроительным ансамблям; произведения ландшафтной архитектуры и садово-паркового искусства (сады, парки, скверы, бульвары), некрополи; объекты археологического наследия;
#
# (в ред. Федеральных законов от 30.11.2010 N 328-ФЗ, от 23.07.2013 N 245-ФЗ, от 22.10.2014 N 315-ФЗ)

# %% [markdown]
# достопримечательные места - творения, созданные человеком, или совместные творения человека и природы, в том числе места традиционного бытования народных художественных промыслов; центры исторических поселений или фрагменты градостроительной планировки и застройки; памятные места, культурные и природные ландшафты, связанные с историей формирования народов и иных этнических общностей на территории Российской Федерации, историческими (в том числе военными) событиями, жизнью выдающихся исторических личностей; объекты археологического наследия; места совершения религиозных обрядов; места захоронений жертв массовых репрессий; религиозно-исторические места.
#
# (в ред. Федеральных законов от 23.07.2013 N 245-ФЗ, от 22.10.2014 N 315-ФЗ)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv', index_col='Регион')
df.head()
# Out:
# C:\Users\po\AppData\Local\Temp\ipykernel_4084\3892383214.py:1: DtypeWarning: Columns (1,45,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data.csv', index_col='Регион')
#                                                                   Объект  \
# Регион
# Смоленская область     Дом, в котором в 1917 г. находился Совет рабоч...
# Новосибирская область                                 Дом Ф.Д. Маштакова
# Смоленская область                                             Дом жилой
# Ярославская область                         Памятник Александру Невскому
# Новосибирская область  Здание городского торгового корпуса, где 14 де...
#
#                        Номер в реестре  название улицы  Комментарий  \
# Регион
# Смоленская область     671510201120006             NaN          NaN
# Новосибирская область  571410013830005             NaN          NaN
# Смоленская область     671510200540005             NaN          NaN
# Ярославская область    761310302740006             NaN          NaN
# Новосибирская область  541510302250006             NaN          NaN
#
#                        Идентификатор дома в ФИАС  FiasAuxSubobjId  \
# Регион
# Смоленская область                           NaN              NaN
# Новосибирская область                        NaN              NaN
# Смоленская область                           NaN              NaN
# Ярославская область                          NaN              NaN
# Новосибирская область                        NaN              NaN
#
#                        FiasAuxObjId  Идентификатор улицы в ФИАС  \
# Регион
# Смоленская область              NaN                         NaN
# Новосибирская область           NaN                         NaN
# Смоленская область              NaN                         NaN
# Ярославская область             NaN                         NaN
# Новосибирская область           NaN                         NaN
#
#                        Идентификатор населенного пункта в ФИАС  \
# Регион
# Смоленская область                                         NaN
# Новосибирская область                                      NaN
# Смоленская область                                         NaN
# Ярославская область                                        NaN
# Новосибирская область                                      NaN
#
#                        Идентификатор внутрегородской территории в ФИАС  ...  \
# Регион                                                                  ...
# Смоленская область                                                 NaN  ...
# Новосибирская область                                              NaN  ...
# Смоленская область                                                 NaN  ...
# Ярославская область                                                NaN  ...
# Новосибирская область                                              NaN  ...
#
#                        Id - идентификатор  признак актуальности  \
# Регион
# Смоленская область                 147449                   NaN
# Новосибирская область              147450                  True
# Смоленская область                 147454                  True
# Ярославская область                147455                  True
# Новосибирская область              147457                  True
#
#                        признак публичности  год постановки ОКН на Госохрану  \
# Регион
# Смоленская область                     NaN                              NaN
# Новосибирская область                  NaN                           2001.0
# Смоленская область                     NaN                              NaN
# Ярославская область                    NaN                              NaN
# Новосибирская область                  NaN                              NaN
#
#                        год проведения реставрации  \
# Регион
# Смоленская область                            NaN
# Новосибирская область                         NaN
# Смоленская область                            NaN
# Ярославская область                           NaN
# Новосибирская область                         NaN
#
#                        параметры, идентифицирующие ФЦП  \
# Регион
# Смоленская область                                 NaN
# Новосибирская область                              NaN
# Смоленская область                                 NaN
# Ярославская область                                NaN
# Новосибирская область                              NaN
#
#                         относительный URL объекта категория объекта  \
# Регион
# Смоленская область     /cdm/v2/heritages/1/147449          heritage
# Новосибирская область  /cdm/v2/heritages/1/147450          heritage
# Смоленская область     /cdm/v2/heritages/1/147454          heritage
# Ярославская область    /cdm/v2/heritages/1/147455          heritage
# Новосибирская область  /cdm/v2/heritages/1/147457          heritage
#
#                        дата создания объекта дата обновления объекта
# Регион
# Смоленская область      2015-10-02T06:46:44Z                     NaN
# Новосибирская область                    NaN    2022-01-31T10:47:19Z
# Смоленская область                       NaN    2023-09-29T09:24:33Z
# Ярославская область                      NaN    2021-12-23T17:14:05Z
# Новосибирская область   2015-12-30T11:42:05Z                     NaN
#
# [5 rows x 52 columns]

# %%
df = df.sort_index()

# %%
indar = np.unique(np.array(df.index))

# %% [markdown]
# Нам необходимо удалить ненужные показатели. Для этого мы транспонируем матрицу
# подсвечиваем NaN и добавляем столбец, содержащий результат применения логического И
# к каждому ряду.

# %%
dft = df.T

# %%
dft['andres'] = dft.apply(lambda row: all(row.isna()), axis=1)

# %%
dft.andres
# Out:
# Объект                                                 False
# Номер в реестре                                        False
# название улицы                                          True
# Комментарий                                             True
# Идентификатор дома в ФИАС                               True
# FiasAuxSubobjId                                         True
# FiasAuxObjId                                            True
# Идентификатор улицы в ФИАС                              True
# Идентификатор населенного пункта в ФИАС                 True
# Идентификатор внутрегородской территории в ФИАС         True
# Идентификатор города в ФИАС                             True
# Идентификатор городских и сельских поселений в ФИАС     True
# Идентификатор района в ФИАС                             True
# Идентификатор автономного округа в ФИАС                 True
# Идентификатор региона в ФИАС                            True
# Идентификатор страны в ФИАС                             True
# Полный адрес                                           False
# На карте                                               False
# Id-Регион                                              False
# учетный номер                                          False
# Id-Категория историко-культурного значения             False
# Категория историко-культурного значения                False
# Id-Тип объекта культурного наследия                     True
# Тип объекта культурного наследия                        True
# Id-Вид объекта                                         False
# Вид объекта                                            False
# описание предмета охраны                               False
# текстовое описание границ                              False
# Id-общая видовая принадлежность                        False
# Id-Принадлежность к Юнеско                             False
# Принадлежность к Юнеско                                False
# Id-Особо ценный объект                                 False
# Особо ценный объект                                    False
# идентификатор ансамбля                                 False
# дата создания                                          False
# GeoId                                                   True
# X                                                       True
# Y                                                       True
# наименование документа                                 False
# Изображение                                            False
# зоны охраны и режимы использования земель              False
# Items                                                  False
# Id - идентификатор                                     False
# признак актуальности                                   False
# признак публичности                                    False
# год постановки ОКН на Госохрану                        False
# год проведения реставрации                             False
# параметры, идентифицирующие ФЦП                        False
# относительный URL объекта                              False
# категория объекта                                      False
# дата создания объекта                                  False
# дата обновления объекта                                False
# Name: andres, dtype: bool

# %%
df = dft[dft.andres != True].T

# %%
df = df.rename(index={'Республика Северная Осетия - Алания': 'alany', 'Ставропольский край': 'stav'})

# %%
len(indar)
# Out:
# 86

# %%
df.columns
# Out:
# Index(['Объект', 'Номер в реестре', 'Полный адрес', 'На карте', 'Id-Регион',
#        'учетный номер', 'Id-Категория историко-культурного значения',
#        'Категория историко-культурного значения', 'Id-Вид объекта',
#        'Вид объекта', 'описание предмета охраны', 'текстовое описание границ',
#        'Id-общая видовая принадлежность', 'Id-Принадлежность к Юнеско',
#        'Принадлежность к Юнеско', 'Id-Особо ценный объект',
#        'Особо ценный объект', 'идентификатор ансамбля', 'дата создания',
#        'наименование документа', 'Изображение',
#        'зоны охраны и режимы использования земель', 'Items',
#        'Id - идентификатор', 'признак актуальности', 'признак публичности',
#        'год постановки ОКН на Госохрану', 'год проведения реставрации',
#        'параметры, идентифицирующие ФЦП', 'относительный URL объекта',
#        'категория объекта', 'дата создания объекта',
#        'дата обновления объекта'],
#       dtype='object')

# %%
# unl = []
for i in np.array(df.loc['alany']['Категория историко-культурного значения']):
    if not i in unl:
        unl.append(i)
unl
# Out:
# ['Федерального значения', 'Регионального значения']

# %%
unl.clear()
unl
# Out:
# []

# %%
len(unl)
# Out:
# 548

# %%
alany = 'alany'

# %%
df.loc[f'{alany}'].loc[((df.loc['alany']['Вид объекта'] == 'Достопримечательное место'))# | (df.loc['alany']['Вид объекта'] == 'Памятник'))
                   & (df.loc['alany']['Категория историко-культурного значения'] == 'Регионального значения')]
# Out:
#                              Объект  Номер в реестре  \
# Регион
# alany   Место общественных собраний  151630461470035
#
#                                              Полный адрес На карте Id-Регион  \
# Регион
# alany   Республика Северная Осетия-Алания, Алагирский ...      NaN        15
#
#        учетный номер Id-Категория историко-культурного значения  \
# Регион
# alany       15-86866                                          2
#
#        Категория историко-культурного значения Id-Вид объекта  \
# Регион
# alany                   Регионального значения              3
#
#                       Вид объекта  ... Id - идентификатор  \
# Регион                             ...
# alany   Достопримечательное место  ...             226743
#
#        признак актуальности признак публичности  \
# Регион
# alany                  True                 NaN
#
#        год постановки ОКН на Госохрану год проведения реставрации  \
# Регион
# alany                           1960.0                        NaN
#
#        параметры, идентифицирующие ФЦП   относительный URL объекта  \
# Регион
# alany                              NaN  /cdm/v2/heritages/3/226743
#
#        категория объекта дата создания объекта дата обновления объекта
# Регион
# alany           heritage                   NaN    2023-05-18T07:43:48Z
#
# [1 rows x 33 columns]

# %%
# df.loc['alany'].loc[(df.loc['alany']['Вид объекта'] == 'Ансамбль')
#                    & (df.loc['alany']['Категория историко-культурного значения'] == 'Федерального значения')]
df.loc['alany']
# Out:
#                                                    Объект  Номер в реестре  \
# Регион
# alany                                    Склеп наземный 3  152110076330226
# alany                                             Ганах 5  152110365750126
# alany                                          Мельница 1  152110076330186
# alany                                             Ганах 6  152110365750066
# alany                                            Кладбище  152110365750046
# ...                                                   ...              ...
# alany    Склеп полуподземный с гладкой фасадной стеной 28  152110076331186
# alany                              Архитектурный комплекс  151620461310006
# alany   Грунтовые погребения, погребения в каменных ящ...  151640610530006
# alany   Дом, в котором на съезде Советов Терской облас...  161410017070006
# alany                                Памятник В.И. Ленину  161410017060006
#
#                                              Полный адрес  \
# Регион
# alany   Республика Северная Осетия-Алания, Пригородный...
# alany   Республика Северная Осетия-Алания, Алагирский ...
# alany   Республика Северная Осетия-Алания, Пригородный...
# alany   Республика Северная Осетия-Алания, Алагирский ...
# alany   Республика Северная Осетия-Алания, Алагирский ...
# ...                                                   ...
# alany   Республика Северная Осетия-Алания, Пригородный...
# alany   Республика Северная Осетия-Алания,Пригородный ...
# alany                                                 NaN
# alany   Республика Северная Осетия-Алания, г. Владикав...
# alany   Республика Северная - Осетия- Алания, г. Влади...
#
#                                                  На карте Id-Регион  \
# Регион
# alany                                                 NaN        15
# alany                                                 NaN        15
# alany                                                 NaN        15
# alany                                                 NaN        15
# alany                                                 NaN        15
# ...                                                   ...       ...
# alany                                                 NaN        15
# alany                                                 NaN        15
# alany                                                 NaN        15
# alany   {"coordinates":[44.679292,43.030311],"type":"P...        15
# alany   {"coordinates":[44.6800430185231,43.0304211955...        15
#
#        учетный номер Id-Категория историко-культурного значения  \
# Регион
# alany      15-180041                                          1
# alany      15-177621                                          1
# alany      15-180008                                          1
# alany      15-177622                                          1
# alany      15-177629                                          1
# ...              ...                                        ...
# alany      15-179783                                          1
# alany       15-85736                                          1
# alany       15-99558                                          1
# alany        15-1032                                          1
# alany        15-1033                                          1
#
#        Категория историко-культурного значения Id-Вид объекта Вид объекта  \
# Регион
# alany                    Федерального значения              1    Памятник
# alany                    Федерального значения              1    Памятник
# alany                    Федерального значения              1    Памятник
# alany                    Федерального значения              1    Памятник
# alany                    Федерального значения              1    Памятник
# ...                                        ...            ...         ...
# alany                    Федерального значения              1    Памятник
# alany                    Федерального значения              2    Ансамбль
# alany                    Федерального значения              2    Ансамбль
# alany                    Федерального значения              1    Памятник
# alany                    Федерального значения              1    Памятник
#
#         ... Id - идентификатор признак актуальности признак публичности  \
# Регион  ...
# alany   ...             329290                 True                 NaN
# alany   ...             327070                 True                 NaN
# alany   ...             329287                 True                 NaN
# alany   ...             327071                 True                 NaN
# alany   ...             327072                 True                 NaN
# ...     ...                ...                  ...                 ...
# alany   ...             329009                 True                 NaN
# alany   ...             225850                 True                 NaN
# alany   ...             238773                 True                 NaN
# alany   ...             150028                 True                 NaN
# alany   ...             150029                 True                 NaN
#
#        год постановки ОКН на Госохрану год проведения реставрации  \
# Регион
# alany                           2020.0                        NaN
# alany                           2020.0                        NaN
# alany                           2020.0                        NaN
# alany                           2020.0                        NaN
# alany                           2020.0                        NaN
# ...                                ...                        ...
# alany                           2020.0                        NaN
# alany                              NaN                        NaN
# alany                              NaN                        NaN
# alany                           1960.0                        NaN
# alany                           1960.0                        NaN
#
#        параметры, идентифицирующие ФЦП   относительный URL объекта  \
# Регион
# alany                              NaN  /cdm/v2/heritages/1/329290
# alany                              NaN  /cdm/v2/heritages/1/327070
# alany                              NaN  /cdm/v2/heritages/1/329287
# alany                              NaN  /cdm/v2/heritages/1/327071
# alany                              NaN  /cdm/v2/heritages/1/327072
# ...                                ...                         ...
# alany                              NaN  /cdm/v2/heritages/1/329009
# alany                              NaN  /cdm/v2/heritages/2/225850
# alany                              NaN  /cdm/v2/heritages/2/238773
# alany                              NaN  /cdm/v2/heritages/1/150028
# alany                              NaN  /cdm/v2/heritages/1/150029
#
#        категория объекта дата создания объекта дата обновления объекта
# Регион
# alany           heritage  2022-07-22T12:56:50Z                     NaN
# alany           heritage  2022-07-22T12:51:28Z                     NaN
# alany           heritage  2022-07-22T12:56:43Z                     NaN
# alany           heritage  2022-07-22T12:51:31Z                     NaN
# alany           heritage  2022-07-22T12:51:33Z                     NaN
# ...                  ...                   ...                     ...
# alany           heritage  2022-07-22T12:54:22Z                     NaN
# alany           heritage                   NaN    2023-11-07T07:29:08Z
# alany           heritage  2016-12-07T15:49:25Z                     NaN
# alany           heritage                   NaN    2023-11-10T06:45:36Z
# alany           heritage                   NaN    2023-11-14T12:47:42Z
#
# [689 rows x 33 columns]

# %%
# df.loc['stav'].loc[((df.loc['stav']['Вид объекта'] == 'Достопримечательное место')) # | (df.loc['stav']['Вид объекта'] == 'Памятник'))
#                    & (df.loc['stav']['Категория историко-культурного значения'] == 'Регионального значения')]
df.loc['stav']
# Out:
#                                                   Объект  Номер в реестре  \
# Регион
# stav                         Дом общественного призрения  261710893610005
# stav                           Могильник "Отстойник - 2"  261640491380006
# stav    Памятник Ксении Ге, следователю Кисловодского ЧК  261710899020005
# stav                                    Курганная группа  261741033890006
# stav                           Могильник "Отстойник - I"  261640491300006
# ...                                                  ...              ...
# stav                                   Дом М.И.Шеховцова  261510224600005
# stav          Бюст Героя Советского Союза Байрамова Н.Х.  261711163690005
# stav                          Здание Присутственных мест  261610247460126
# stav                        Здание курортной поликлиники  261610419760005
# stav                   Памятник героям гражданской войны  261711163930005
#
#                                              Полный адрес  \
# Регион
# stav    Ставропольский край, г. Ставрополь, р-н Октябр...
# stav                                                  NaN
# stav    Ставропольский край, г. Кисловодск, Бульвар Ку...
# stav                                                  NaN
# stav                                                  NaN
# ...                                                   ...
# stav    Ставропольский край, г.Ессентуки,  ул.Советска...
# stav    Ставропольский край, Новоселицкий район, с. До...
# stav    Ставропольский край, г. Ставрополь, Советская ...
# stav    Ставропольский край, город Пятигорск, пр. Киро...
# stav    Ставропольский край, Грачевский район, с. Кугу...
#
#                                                  На карте Id-Регион  \
# Регион
# stav                                                  NaN        26
# stav                                                  NaN        26
# stav                                                  NaN        26
# stav                                                  NaN        26
# stav                                                  NaN        26
# ...                                                   ...       ...
# stav    {"coordinates":[42.8567308134917,44.0451160854...        26
# stav                                                  NaN        26
# stav    {"coordinates":[41.9714944576717,45.0472226075...        26
# stav    {"coordinates":[43.0830789913993,44.0369468327...        26
# stav                                                  NaN        26
#
#        учетный номер Id-Категория историко-культурного значения  \
# Регион
# stav       26-118423                                          2
# stav        26-90196                                          1
# stav       26-122895                                          2
# stav       26-134276                                          1
# stav        26-90194                                          1
# ...              ...                                        ...
# stav        26-51044                                          2
# stav       26-155561                                          2
# stav        26-49513                                          1
# stav        26-73230                                          2
# stav       26-121983                                          2
#
#        Категория историко-культурного значения Id-Вид объекта Вид объекта  \
# Регион
# stav                    Регионального значения              1    Памятник
# stav                     Федерального значения              1    Памятник
# stav                    Регионального значения              1    Памятник
# stav                     Федерального значения              2    Ансамбль
# stav                     Федерального значения              1    Памятник
# ...                                        ...            ...         ...
# stav                    Регионального значения              1    Памятник
# stav                    Регионального значения              1    Памятник
# stav                     Федерального значения              1    Памятник
# stav                    Регионального значения              1    Памятник
# stav                    Регионального значения              1    Памятник
#
#         ... Id - идентификатор признак актуальности признак публичности  \
# Регион  ...
# stav    ...             263842                 True                 NaN
# stav    ...             229753                 True                 NaN
# stav    ...             262242                 True                 NaN
# stav    ...             273905                 True                 NaN
# stav    ...             229750                 True                 NaN
# ...     ...                ...                  ...                 ...
# stav    ...             196300                 true                 NaN
# stav    ...             306415                 True                 NaN
# stav    ...             214552                 True                 NaN
# stav    ...             214719                 True                 NaN
# stav    ...             279715                 True                 NaN
#
#        год постановки ОКН на Госохрану год проведения реставрации  \
# Регион
# stav                               NaN                        NaN
# stav                               NaN                        NaN
# stav                               NaN                        NaN
# stav                               NaN                        NaN
# stav                               NaN                        NaN
# ...                                ...                        ...
# stav                               NaN                        NaN
# stav                               NaN                        NaN
# stav                               NaN                        NaN
# stav                               NaN                        NaN
# stav                               NaN                        NaN
#
#        параметры, идентифицирующие ФЦП   относительный URL объекта  \
# Регион
# stav                               NaN  /cdm/v2/heritages/1/263842
# stav                               NaN  /cdm/v2/heritages/1/229753
# stav                               NaN  /cdm/v2/heritages/1/262242
# stav                               NaN  /cdm/v2/heritages/2/273905
# stav                               NaN  /cdm/v2/heritages/1/229750
# ...                                ...                         ...
# stav                               NaN  /cdm/v2/heritages/1/196300
# stav                               NaN  /cdm/v2/heritages/1/306415
# stav                               NaN  /cdm/v2/heritages/1/214552
# stav                               NaN  /cdm/v2/heritages/1/214719
# stav                               NaN  /cdm/v2/heritages/1/279715
#
#        категория объекта дата создания объекта дата обновления объекта
# Регион
# stav            heritage                   NaN    2022-06-10T13:12:04Z
# stav            heritage                   NaN    2023-04-14T09:57:11Z
# stav            heritage                   NaN    2022-10-19T07:11:24Z
# stav            heritage  2017-09-18T14:03:15Z                     NaN
# stav            heritage                   NaN    2023-12-13T07:35:56Z
# ...                  ...                   ...                     ...
# stav            heritage                   NaN    2023-11-07T07:31:42Z
# stav            heritage                   NaN    2022-08-09T08:32:48Z
# stav            heritage                   NaN    2023-12-18T07:02:24Z
# stav            heritage                   NaN    2022-10-19T07:52:21Z
# stav            heritage  2017-10-20T05:42:13Z                     NaN
#
# [2439 rows x 33 columns]

# %%
np.array([dpst.iloc[-3].get(['Полный адрес']), dpst.iloc[-1].get(['Полный адрес'])])
# Out:
# array([['Ставропольский край, г. Ессентуки, Лечебный парк'],
#        ['Ставропольский край, Петровский район, г. Светлоград']],
#       dtype=object)

# %%
unl
# Out:
# ['Памятник', 'Ансамбль', 'Достопримечательное место']

# %%
columns_to_exclude = ['категория объекта', ]

# %%
unl.clear()
unl
# Out:
# []

# %%
np.unique(indar)

# %%
Alany = df[df.index == 'Республика Северная Осетия - Алания']

# %%
Alany.Объект.tolist()

# %%
np.all(Alany['Идентификатор дома в ФИАС'].isna())

# %%
Alany.isna()

# %%
ALT = Alany.T

# %%
ALT['and_result'] = ALT.apply(lambda row: all(row.isna()), axis=1)

# %%
ALT.and_result

# %%
np.count_nonzero(np.array(Alany.and_result) == False)

# %%
ALT[ALT.and_result != True]
